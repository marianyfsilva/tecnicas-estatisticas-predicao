# %%
# Importação da biblioteca padrão ggplot2
library(ggplot2)

# %%
# Leitura dos dados
csv_content <- read.csv("DADOS-CRIMES-UCI.csv")

print(paste("O número de colunas é: ", ncol(csv_content))) # deve ser 7
print(paste("O número de linhas é: ", nrow(csv_content)))  # deve ser 2128

print(paste("O número de colunas é: ", ncol(csv_content)))
print(paste("O número de linhas é: ", nrow(csv_content)))

# Variável resposta
total_crimes <- csv_content["ViolentCrimesPerPop_nonViolPerPop"]
# Variaveis explicativas
population <- csv_content["population"]
indice_renda_per_capta <- csv_content["perCapInc"]
porcentagem_nivel_basico <- csv_content["PctLess9thGrade"]
porcentagem_sem_nivel_medio <- csv_content["PctNotHSGrad"]
porcentagem_com_nivel_superior <- csv_content["PctBSorMore"]
porcentagem_desempregados <-  csv_content["PctUnemployed"]

data = data.frame(csv_content)

# imprimir início do data frame
head(data)
# Out:
# [1] "O número de colunas é:  9"
# [1] "O número de linhas é:  1830"
# [1] "O número de colunas é:  9"
# [1] "O número de linhas é:  1830"
#   ViolentCrimesPerPop_nonViolPerPop population perCapInc PctLess9thGrade
# 1 15143.78                          10005      10086     13.46
# 2  2958.63                          10014       9106     12.71
# 3  6943.12                          10019       9066     21.54
# 4  4138.68                          10023      13246      3.65
# 5 13828.14                          10026      10376     23.98
# 6  2346.81                          10030      15128     14.96
#   PctNotHSGrad PctBSorMore PctUnemployed
# 1 33.24        14.50        8.15
# 2 27.60        29.64        5.68
# 3 40.94        11.42        8.68
# 4  7.89        21.17        4.38
# 5 49.73         8.74       11.64
# 6 25.05        16.09        2.36

# %%
print("Diagrama de dispersão")
print("[Populacao] X [Total de crimes violentos e não violentos]")

g1 <- ggplot(data=data, aes(x=populacao, y=total_crimes))+
  geom_point() +
  labs(x = 'Populacao', y = 'Total de crimes violentos e não violentos') +
  theme_minimal()
g1 + geom_smooth(method = 'lm', se = F)
# Out:
# [1] "Diagrama de dispersão"
# [1] "[Populacao] X [Total de crimes violentos e não violentos]"
# ERROR while rich displaying an object: Error in FUN(X[[i]], ...): object 'populacao' not found
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 6. repr::mime2repr[[mime]](obj)
# 7. repr_text.default(obj)
# 8. paste(capture.output(print(obj)), collapse = "\n")
# 9. capture.output(print(obj))
# 10. withVisible(...elt(i))
# 11. print(obj)
# 12. print.ggplot(obj)
# 13. ggplot_build(x)
# 14. ggplot_build.ggplot(x)
# 15. by_layer(function(l, d) l$compute_aesthetics(d, plot))
# 16. f(l = layers[[i]], d = data[[i]])
# 17. l$compute_aesthetics(d, plot)
# 18. f(..., self = self)
# 19. scales_add_defaults(plot$scales, data, aesthetics, plot$plot_env)
# 20. lapply(aesthetics[new_aesthetics], eval_tidy, data = data)
# 21. FUN(X[[i]], ...)
# plot without title

# %%
print("Diagrama de dispersão")
print("[Indice de Renda per capta] X [Total de crimes violentos e não violentos]")

g2 <- ggplot(data=data, aes(x=indice_renda_per_capta, y=total_crimes))+
  geom_point() +
  labs(x = 'Indice de Renda per capta', y = 'Total de crimes violentos e não violentos') +
  theme_minimal()

g2 + geom_smooth(method = 'lm', se = F)
# Out:
# [1] "Diagrama de dispersão"
# [1] "[Indice de Renda per capta] X [Total de crimes violentos e não violentos]"
# ERROR while rich displaying an object: Error in FUN(X[[i]], ...): object 'indice_renda_per_capta' not found
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 6. repr::mime2repr[[mime]](obj)
# 7. repr_text.default(obj)
# 8. paste(capture.output(print(obj)), collapse = "\n")
# 9. capture.output(print(obj))
# 10. withVisible(...elt(i))
# 11. print(obj)
# 12. print.ggplot(obj)
# 13. ggplot_build(x)
# 14. ggplot_build.ggplot(x)
# 15. by_layer(function(l, d) l$compute_aesthetics(d, plot))
# 16. f(l = layers[[i]], d = data[[i]])
# 17. l$compute_aesthetics(d, plot)
# 18. f(..., self = self)
# 19. scales_add_defaults(plot$scales, data, aesthetics, plot$plot_env)
# 20. lapply(aesthetics[new_aesthetics], eval_tidy, data = data)
# 21. FUN(X[[i]], ...)
# plot without title

# %%
print("Diagrama de dispersão")
print("[Pessoas com nível básico incompleto] X [Total de crimes violentos e não violentoss]")

g3 <- ggplot(data=data, aes(x=porcentagem_nivel_basico, y=total_crimes))+
  geom_point() +
  labs(x = '% Pessoas com nível básico incompleto', y = 'Total de crimes violentos e não violentoss') +
  theme_minimal()
g3 + geom_smooth(method = 'lm', se = F)
# Out:
# [1] "Diagrama de dispersão"
# [1] "[Pessoas com nível básico incompleto] X [% Roubos / 100 mil habitantes]"
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
print("Diagrama de dispersão")
print("[Pessoas com nível médio incompleto] X [Total de crimes violentos e não violentos]")

g4 <- ggplot(data=data, aes(x=porcentagem_sem_nivel_medio, y=total_crimes))+
  geom_point() +
  labs(x = '% Pessoas com nível médio incompleto', y = 'Total de crimes violentos e não violentos') +
  theme_minimal()

g4 + geom_smooth(method = 'lm', se = F)
# Out:
# [1] "Diagrama de dispersão"
# [1] "[Pessoas com nível médio incompleto] X [% Roubos / 100 mil habitantes]"
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
print("Diagrama de dispersão")
print("[Pessoas com nível superior completo] X [Total de crimes violentos e não violentos]")

g5 <- ggplot(data=data, aes(x=porcentagem_com_nivel_superior, y=total_crimes))+
  geom_point() +
  labs(x = '% Pessoas com nível superior completo', y = 'Total de crimes violentos e não violentos') +
  theme_minimal()

g5 + geom_smooth(method = 'lm', se = F)
# Out:
# [1] "Diagrama de dispersão"
# [1] "[Pessoas com nível superior completo] X [% Roubos / 100 mil habitantes]"
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
print("Diagrama de dispersão")
print("[Desempregados] X [% Roubos / 100 mil habitantes]")

g6 <- ggplot(data=data, aes(x=porcentagem_desempregados, y=total_crimes))+
  geom_point() +
  labs(x = '% Desempregados', y = 'Total de crimes violentos e não violentos') +
  theme_minimal()

g6 + geom_smooth(method = 'lm', se = F)
# Out:
# [1] "Diagrama de dispersão"
# [1] "[Desempregados] X [% Roubos / 100 mil habitantes]"
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
# Coeficiente lineares de Person

print("populacao")
cor(data$populacao, data$total_crimes)

print("indice_renda_per_capta")
cor(data$indice_renda_per_capta, data$total_crimes)

print("porcentagem_nivel_basico")
cor(data$porcentagem_nivel_basico, data$total_crimes)

print("porcentagem_sem_nivel_medio")
cor(data$porcentagem_sem_nivel_medio, data$total_crimes)

print("porcentagem_com_nivel_superior")
cor(data$porcentagem_com_nivel_superior, data$total_crimes)

print("porcentagem_desempregados")
cor(data$porcentagem_desempregados, data$total_crimes)
# Out:
# [1] "populacao"
# [1] 0.4701838
# [1] "indice_renda_per_capta"
# [1] -0.2672676
# [1] "porcentagem_nivel_basico"
# [1] 0.3173325
# [1] "porcentagem_sem_nivel_medio"
# [1] 0.4195055
# [1] "porcentagem_com_nivel_superior"
# [1] -0.2671398
# [1] "porcentagem_desempregados"
# [1] 0.4013658

# %%
# Ajuste do modelo
# Out:
#                    (Intercept)                      populacao
#                  -5.044918e+02                   2.998933e-04
#         indice_renda_per_capta       porcentagem_nivel_basico
#                   2.179688e-03                  -2.780216e+01
#    porcentagem_sem_nivel_medio porcentagem_com_nivel_superior
#                   2.596494e+01                   6.901725e+00
#      porcentagem_desempregados
#                   2.276775e+01

# %%
# Resumo do modelo

# %%
# Analise dos coeficientes calculados

# %%
# Análise de resíduos

# %%
# Teste de normalidade

# %%
# Conclusões
